# %%
import pandas as pd

# %%
df=pd.read_csv('bike_sales_india.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year of Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         10000 non-null  object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df.nunique()
# Out:
# State                         10
# Avg Daily Distance (km)     5535
# Brand                          8
# Model                         40
# Price (INR)                 9863
# Year of Manufacture           10
# Engine Capacity (cc)         901
# Fuel Type                      3
# Mileage (km/l)              5404
# Owner Type                     3
# Registration Year             10
# Insurance Status               3
# Seller Type                    2
# Resale Price (INR)         10000
# City Tier                      4
# dtype: int64

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.1 MB 2.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.1 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.1 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.1 MB 2.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.1 MB 2.2 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/11.1 MB 2.1 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/11.1 MB 2.1 MB/s eta 0:00:04
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
for i in df.select_dtypes(include=["object"]).columns:
  df[i]= encoder.fit_transform(df[i])

# %%
df
# Out:
#       State  Avg Daily Distance (km)  Brand  Model  Price (INR)  \
# 0         2                    68.84      5     17       252816
# 1         6                    23.80      0     10       131100
# 2         3                    27.67      3      0       201016
# 3         2                    62.85      4     23       132482
# 4         3                    10.62      7     12       231796
# ...     ...                      ...    ...    ...          ...
# 9995      1                    67.72      1     25        95040
# 9996      0                    19.94      0      7       110369
# 9997      9                    79.95      0     27       313806
# 9998      3                    16.07      2      9       204068
# 9999      9                    51.16      5      8       323583
#
#       Year of Manufacture  Engine Capacity (cc)  Fuel Type  Mileage (km/l)  \
# 0                    2021                   672          0           78.41
# ...

# %%
df.isnull().sum()
# Out:
# State                      0
# Avg Daily Distance (km)    0
# Brand                      0
# Model                      0
# Price (INR)                0
# Year of Manufacture        0
# Engine Capacity (cc)       0
# Fuel Type                  0
# Mileage (km/l)             0
# Owner Type                 0
# Registration Year          0
# Insurance Status           0
# Seller Type                0
# Resale Price (INR)         0
# City Tier                  0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [State, Avg Daily Distance (km), Brand, Model, Price (INR), Year of Manufacture, Engine Capacity (cc), Fuel Type, Mileage (km/l), Owner Type, Registration Year, Insurance Status, Seller Type, Resale Price (INR), City Tier]
# Index: []

# %%
avg_price = df['Price (INR)'].mean()
avg_price
# the average price of bikes
# Out:
# np.float64(224328.7224)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Price (INR)'], kde=True, color='skyblue')
plt.title('Distribution of Bike Prices')
plt.xlabel('Price (INR)')
plt.ylabel('Frequency')
plt.show()
# Distribution of Bike Prices

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='State', y='Avg Daily Distance (km)', palette='Set2')
plt.xticks(rotation=45)
plt.title('Average Daily Distance by State')
plt.show()
# How does average daily distance vary by state?
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\1736401905.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='State', y='Avg Daily Distance (km)', palette='Set2')

# %%
df['Brand'].value_counts().plot(kind='bar', color='coral', figsize=(10, 5))
plt.title('Most Popular Bike Brands')
plt.ylabel('Count')
plt.xlabel('Brand')
plt.xticks(rotation=45)
plt.show()
# Most Popular Bike Brands

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# ...
# Using cached plotly-6.0.1-py3-none-any.whl (14.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: C:\Users\Sreeja S\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

# %%
df[['Engine Capacity (cc)', 'Mileage (km/l)']].corr()
# Out:
#                       Engine Capacity (cc)  Mileage (km/l)
# Engine Capacity (cc)              1.000000       -0.006772
# Mileage (km/l)                   -0.006772        1.000000

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df['Depreciation (%)'] = ((df['Price (INR)'] - df['Resale Price (INR)']) / df['Price (INR)']) * 100
sns.histplot(df['Depreciation (%)'], bins=20, kde=True, color='purple')
plt.title('Distribution of Depreciation (%)')
plt.show()
# How does resale price compared to original price?

# %%
sns.countplot(data=df, x='Fuel Type', palette='Set1')
plt.title('Fuel Type Distribution')
plt.show()
# Bike counts by fuel type
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\2460775397.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.boxplot(data=df, x='Seller Type', y='Resale Price (INR)', palette='Set3')
plt.title("Resale Price by Seller Type")
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\1442107811.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df.groupby('Fuel Type')['Mileage (km/l)'].mean().plot(kind='bar', color='teal')
plt.ylabel("Average Mileage (km/l)")
plt.title("Average Mileage by Fuel Type")
plt.show()

# %%
sns.violinplot(data=df, x='City Tier', y='Price (INR)', palette='pastel')
plt.title("Bike Prices Across City Tiers")
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\2738062718.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df.groupby('Year of Manufacture')['Price (INR)'].mean().plot(marker='o', color='green')
plt.title("Average Price by Year of Manufacture")
plt.ylabel("Avg Price (INR)")
plt.grid(True)
plt.show()

# %%
sns.countplot(data=df, x='Owner Type', order=df['Owner Type'].value_counts().index, palette='cubehelix')
plt.title("Bike Count by Owner Type")
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\3544876680.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.scatterplot(data=df, x='Mileage (km/l)', y='Resale Price (INR)', hue='Fuel Type', palette='pastel')
plt.title("Mileage vs Resale Price")
plt.show()

# %%
sns.boxplot(data=df, x='Insurance Status', y='Resale Price (INR)', palette='cool')
plt.title("Resale Value by Insurance Status")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\450878804.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df, x='Brand', y='Engine Capacity (cc)', palette='Set1')
plt.title("Engine Capacity Across Brands")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\3642202105.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df['Registration Year'].value_counts().sort_index().plot(kind='bar', color='slateblue')
plt.title("Bike Registrations Over the Years")
plt.xlabel("Registration Year")
plt.ylabel("Count")
plt.show()

# %%
sample_df = df.sample(30)
plt.figure(figsize=(12,6))
plt.plot(sample_df['Model'], sample_df['Price (INR)'], label='Original Price', color='orange')
plt.plot(sample_df['Model'], sample_df['Resale Price (INR)'], label='Resale Price', color='blue')
plt.xticks(rotation=90)
plt.legend()
plt.title("Original vs Resale Prices for Sample Bikes")
plt.show()

# %%
top_mileage = df[['Model', 'Mileage (km/l)']].drop_duplicates(subset='Model')
top_mileage = top_mileage.sort_values(by='Mileage (km/l)', ascending=False).head(10)

sns.barplot(x='Mileage (km/l)', y='Model', data=top_mileage, palette='Greens_r')
plt.title('Top 10 High Mileage Bike Models')
plt.xlabel('Mileage (km/l)')
plt.ylabel('Bike Model')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sreeja S\AppData\Local\Temp\ipykernel_25080\1274052633.py:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
